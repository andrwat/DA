# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Set some Pandas options
#pd.set_option('max_columns', 30)
#pd.set_option('max_rows', 20)

# Default Plotting Size
#mpl.rc("figure", figsize=(20, 8))

# Store data in a consistent place
DATA_DIR = '../data/'

# %%
hsim = pd.read_csv(DATA_DIR + 'hsi_monthly.csv')
hsim.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count    341.000000    341.000000    341.000000    341.000000  3.410000e+02
# mean   12897.978328  13523.158798  12224.694252  12950.686334  6.308581e+08
# std     7023.468819   7285.907875   6678.284555   7024.761336  8.973668e+08
# min     2086.700000   2317.500000   1894.900000   2138.400000  0.000000e+00
# 25%     7674.400000   8339.900000   7351.680000   7936.200000  0.000000e+00
# 50%    12306.260000  13126.150000  11856.340000  12477.600000  0.000000e+00
# 75%    19414.620000  20272.380000  18302.840000  19482.570000  1.433367e+09
# max    31783.470000  31958.410000  26746.630000  31352.580000  3.719903e+09
#
#           Adj Close  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# count    341.000000           0           0           0            0
# mean   12950.686334         NaN         NaN         NaN          NaN
# std     7024.761336         NaN         NaN         NaN          NaN
# ...

# %%
hsim
# Out:
#          Date      Open      High       Low     Close      Volume  Adj Close  \
# 0      1/4/15  24955.20  25297.80  24926.11  25275.64  2963513800   25275.64
# 1      2/3/15  24996.76  25113.20  23677.06  24900.89  1779316100   24900.89
# 2      2/2/15  24347.27  25101.96  24226.29  24823.29  1453331700   24823.29
# 3      2/1/15  23699.20  24995.08  23312.50  24507.05  1948871100   24507.05
# 4     1/12/14  23678.00  24189.59  22529.75  23605.04  2588409900   23605.04
# 5     3/11/14  24133.45  24313.06  23252.63  23987.45  2012868900   23987.45
# 6     3/10/14  22691.59  24046.40  22565.60  23998.06  1640102300   23998.06
# 7      1/9/14  24703.74  25362.98  22855.04  22932.98  1783195400   22932.98
# 8      1/8/14  24594.23  25243.16  24190.93  24742.06  1419447500   24742.06
# 9      2/7/14  23326.53  24912.22  23126.68  24756.85  1529905500   24756.85
# 10     3/6/14  23327.51  23397.77  22802.10  23190.72  1478374400   23190.72
# ...

# %%
hsim.drop(hsim.columns[[7,8,9,10]],1,inplace=True)

# %%
hsim
# Out:
#          Date      Open      High       Low     Close      Volume  Adj Close
# 0      1/4/15  24955.20  25297.80  24926.11  25275.64  2963513800   25275.64
# 1      2/3/15  24996.76  25113.20  23677.06  24900.89  1779316100   24900.89
# 2      2/2/15  24347.27  25101.96  24226.29  24823.29  1453331700   24823.29
# 3      2/1/15  23699.20  24995.08  23312.50  24507.05  1948871100   24507.05
# 4     1/12/14  23678.00  24189.59  22529.75  23605.04  2588409900   23605.04
# 5     3/11/14  24133.45  24313.06  23252.63  23987.45  2012868900   23987.45
# 6     3/10/14  22691.59  24046.40  22565.60  23998.06  1640102300   23998.06
# 7      1/9/14  24703.74  25362.98  22855.04  22932.98  1783195400   22932.98
# 8      1/8/14  24594.23  25243.16  24190.93  24742.06  1419447500   24742.06
# 9      2/7/14  23326.53  24912.22  23126.68  24756.85  1529905500   24756.85
# 10     3/6/14  23327.51  23397.77  22802.10  23190.72  1478374400   23190.72
# ...

# %%
hsim['Range']=hsim['Close'] - hsim['Open']

# %%
hsim['Pct'] = hsim['Range']/hsim['Open']

# %%
hsimup = hsim[hsim.Pct >= 0].sort('Pct')

# %%
hsimdown = hsim[hsim.Pct < 0].sort('Pct')

# %%
hsimup.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count    200.000000    200.000000    200.000000    200.000000  2.000000e+02
# mean   12421.180100  13273.330650  12138.725600  13046.458250  5.823937e+08
# std     6881.818091   7275.725532   6730.903461   7155.235795  8.257190e+08
# min     2086.700000   2379.100000   1894.900000   2302.800000  0.000000e+00
# 25%     6719.175000   7375.325000   6608.250000   7236.775000  0.000000e+00
# 50%    12226.270000  12914.270000  11907.290000  12876.790000  0.000000e+00
# 75%    18566.842500  19871.897500  18118.010000  19797.840000  1.338002e+09
# max    27142.470000  31958.410000  26746.630000  31352.580000  3.226831e+09
#
#           Adj Close        Range         Pct
# count    200.000000   200.000000  200.000000
# mean   13046.458250   625.278150    0.055121
# std     7155.235795   660.731148    0.050240
# min     2302.800000     0.000000    0.000000
# 25%     7236.775000   184.547500    0.019598
# ...

# %%
hsimup.boxplot('Range')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f2043e40550>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2043e4b410>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2043e56710>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2043e560d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f2043e407d0>,
#   <matplotlib.lines.Line2D at 0x7f2043e40d90>]}

# %%
hsimup.boxplot('Pct')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f20446f8250>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2044683210>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f204468e510>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2044683e90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f20446f84d0>,
#   <matplotlib.lines.Line2D at 0x7f20446f8b90>]}

# %%
hsimdown.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count    141.000000    141.000000    141.000000    141.000000  1.410000e+02
# mean   13574.287872  13877.524965  12346.635603  12814.839645  6.996019e+08
# std     7189.980265   7311.549103   6624.921993   6858.442895  9.891345e+08
# min     2224.800000   2317.500000   1960.900000   2138.400000  0.000000e+00
# 25%     9098.600000   9316.270000   8189.000000   8543.100000  0.000000e+00
# 50%    13068.300000  13236.980000  11260.200000  11942.960000  0.000000e+00
# 75%    20582.680000  20975.300000  18378.140000  18629.520000  1.592387e+09
# max    31783.470000  31897.490000  26093.960000  28643.610000  3.719903e+09
#
#           Adj Close        Range         Pct
# count    141.000000   141.000000  141.000000
# mean   12814.839645  -759.448227   -0.056487
# std     6858.442895   845.868463    0.057304
# min     2138.400000 -4509.500000   -0.441856
# 25%     8543.100000 -1037.170000   -0.079508
# ...

# %%
hsimdown.boxplot('Range')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f20445d0450>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f20445dd310>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f20445e7610>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f20445ddf90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f20445d06d0>,
#   <matplotlib.lines.Line2D at 0x7f20445d0d90>]}

# %%
hsimdown.boxplot('Pct')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f204450d750>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2044518610>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2044524910>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f20445242d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f204450d8d0>,
#   <matplotlib.lines.Line2D at 0x7f204450df90>]}

# %%
hsimup['Pct'].median()
# Out:
# 0.0427150111601392

# %%
hsimup['Range'].median()
# Out:
# 435.1899999999987

# %%
hsimdown['Pct'].median()
# Out:
# -0.037946028097752695

# %%
hsimdown['Range'].median()
# Out:
# -475.3600000000006

# %%
hsimup
# Out:
#          Date      Open      High       Low     Close      Volume  Adj Close  \
# 340  31/12/86   2568.30   2568.30   2568.30   2568.30           0    2568.30
# 220   2/12/96  13446.70  13525.40  12736.40  13451.50           0   13451.50
# 116    1/8/05  14892.73  15508.57  14734.43  14903.55   390407200   14903.55
# 274    1/6/92   6099.40   6179.00   5744.30   6103.90           0    6103.90
# 277    2/3/92   4930.60   5113.90   4844.30   4938.30           0    4938.30
# 228    1/4/96  10945.00  11213.50  10712.70  10964.50           0   10964.50
# 109    1/3/06  15768.21  15973.01  15348.22  15805.04   375937600   15805.04
# 48     1/4/11  23664.48  24468.64  23468.20  23720.81  1457782400   23720.81
# 233   2/11/95   9789.60   9882.40   9259.30   9813.30           0    9813.30
# 52    1/12/10  22973.80  23612.25  22392.67  23035.45  1207300000   23035.45
# 64    1/12/09  21813.42  22593.72  20932.77  21872.50  1292214400   21872.50
# ...

# %%
hsimup['Pct'].hist(bins=100)

# %%
hsimdown['Pct'].hist(bins=100)

# %%
hsimup_nool=hsimup['Pct'].drop(hsimup.tail(3).index)

# %%
hsimdown_nool=hsimdown['Pct'][3:]

# %%
hsimup_nool.describe()
# Out:
# count    197.000000
# mean       0.051681
# std        0.041656
# min        0.000000
# 25%        0.019551
# 50%        0.042169
# 75%        0.073064
# max        0.210189
# Name: Pct, dtype: float64

# %%
hsimdown_nool.describe()
# Out:
# count    138.000000
# mean      -0.050771
# std        0.040273
# min       -0.154684
# 25%       -0.077276
# 50%       -0.036847
# 75%       -0.019683
# max       -0.000322
# Name: Pct, dtype: float64
